# %% [markdown]
# ## Testing

# %%
from box import ConfigBox
ali ={
    'name' :'Ali khan',
    'age': 20
}

# %%
new_dect = ConfigBox(ali)

# %%
new_dect
# Out:
# ConfigBox({'name': 'Ali khan', 'age': 20})

# %%
new_dect.age
# Out:
# 20

# %%
def normal(x,y):
    return x+y

# %%
normal(2,3)
# Out:
# 5

# %%
normal(2.2,3.4)
# Out:
# 5.6

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def some(x:int,y:float):
    return x+y

# %%
some(2,3.3)
# Out:
# 5.3

# %%
some(1,2)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 some(1,2)
#
# File c:\py.aman\Data_Science-Projects\Data_Science-Projects\siddvenv\Lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'int'> to <function some at 0x0000024FC9F12090> does not match annotation type <class 'float'>
